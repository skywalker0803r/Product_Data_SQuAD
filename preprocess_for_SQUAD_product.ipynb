# %%
import pandas as pd
from tqdm import tqdm_notebook as tqdm
df = pd.read_excel('combined_excel.xlsx',index_col=0)
print(df.shape)
df.head(3)
# Out:
# (3643, 17)
#                                                   59  \
# 3  FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4  NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 5  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
#
#                                                  45A  \
# 3  MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4  PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# 5  + COMMODITY: LLDPE TAISOX 3470+ QUANTITY: 32.0...
#
#                                                  46A  \
# 3  1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4  1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 5  1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
#
#                                                  47A               31D  \
# 3  1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...      210321TAIWAN
# 4  (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...      210221TAIWAN
# 5  +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...  210315 IN TAIWAN
#
#       44C                                    48  \
# 3  210228      21/(REFER FIELD 47A CLAUSE NO.8)
# 4     NaN                                   021
# 5  210215  10/AFTER DATE OF TRANSPORT DOCUMENTS
#
#                                                  71D  \
# 3  ALL BANK CHARGES OUTSIDE INDIA ARETO THE ACCOU...
# 4                                                NaN
# 5  ALL BANKING CHARGES OUTSIDE VIETNAMINCLUDING R...
#
#                                                   78  \
# 3  +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4  IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 5  + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
#
#                                                   50          51A  \
# 3  OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...          NaN
# 4  AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...          NaN
# 5  MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...  VBAAVNVX310
#
#                LCNO                from EXPNO  \
# 3   6281MLC00000321  017-202101-03.xlsx    11
# 4           L072875  017-202101-03.xlsx    27
# 5  2100ILS210100001  017-202101-03.xlsx    18
#
#                                                 LCBK  \
# 3  ICICI BANK LTD.,\nSHALIMAR TOWER, 31/54 M.G.MA...
# 4       NATIONAL COMMERCIAL BANK, THE\n(HEAD OFFICE)
# 5  VIET NAM BANK FOR AGRICULTURE \nAND RURAL DEVE...
#
#                                                  CU1  \
# 3  OJUS PETROCHEMICALS LLPC 289 NIRALA\n NAGAR LU...
# 4  AHMED SAEED AFIFI FACTORY CO. FORRE\nSINS LTD....
# 5  MINH KHANG CHEMICAL TRADINGJOINT ST\nOCK COMPA...
#
#                                                 SPEC
# 3                                MASS PVC RESIN B-57
# 4                        (鄰苯二甲酐)\nPHTHALIC ANHYDRIDE
# 5  LINEAR LOW DENSITY\nPOLYETHYLENE RESIN\nTAISOX...

# %% [markdown]
# # 去除不必要的東西

# %%
import re

def preprocess(x):
    x = re.sub('[\u4e00-\u9fa5]', '', x) # 1.去除中文
    x = re.sub('[’!"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~，。,.]', '', x) # 2.去除標點符號
    x = x.replace('\n', '').replace('\r', '').replace('\t', '') # 3.去除換行符號
    x = str.strip(x) # 4.移除左右空白
    return x

df['45A'] = df['45A'].apply(preprocess)
df['SPEC'] = df['SPEC'].apply(preprocess)
df.loc[:,['45A','SPEC']].head()
# Out:
#                                                  45A  \
# 3  MASS PVC RESIN B-57QUANTITY 175 MT AT 1300 USD...
# 4  PHTHALIC ANHYDRIDE PAQUANTITY  306 MT UNIT PRI...
# 5  COMMODITY LLDPE TAISOX 3470 QUANTITY 320MT 2FC...
# 7  COMMODITY                                     ...
# 9  COMMODITY                                     ...
#
#                                               SPEC
# 3                              MASS PVC RESIN B-57
# 4                               PHTHALIC ANHYDRIDE
# 5  LINEAR LOW DENSITYPOLYETHYLENE RESINTAISOX 3470
# 7                  POLYESTER PARTIALYORIENTED YARN
# 9                          POLYESTER FILAMENT YARN

# %% [markdown]
# # 寶典標註

# %%
import numpy as np

寶典 = pd.read_excel('台塑企業_ 產品寶典20210303.xlsx')
產品集合 = set(寶典['品名'].values)
def Collection_method(df,產品集合):
    labels = {}
    for i in tqdm(df.index):
        products = []
        for p in 產品集合:# 在寶典中搜索
            if p in df.loc[i,'45A']: 
                products.append(p)
        try:
            labels[i] = max(products,key=len) # 選最長的產品
        except:
            labels[i] = np.nan # 找不到就算了
    predict = pd.DataFrame(index=labels.keys(),columns=['Baodian_predict'])
    predict['Baodian_predict'] = labels.values()
    return predict
predict = Collection_method(df,產品集合)
df = df.join(predict)
df
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/3643 [00:00<?, ?it/s]
#                                                      59  \
# 3     FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4     NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 5     FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 7     NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 9     NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# ...                                                 ...
# 8403  NAN YA PLASTICS CORPORATION_x000D_\nPETROCHEMI...
# 8413  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 8414  FORMOSA CHEMICALS AND FIBRE CORP._x000D_\nADDR...
# 8415  FORMOSA CHEMICALS AND FIBRE CORP._x000D_\nADDR...
# 8416  FORMOSA CHEMICALS AND FIBRE CORP._x000D_\nADDR...
#
#                                                     45A  \
# 3     MASS PVC RESIN B-57QUANTITY 175 MT AT 1300 USD...
# 4     PHTHALIC ANHYDRIDE PAQUANTITY  306 MT UNIT PRI...
# 5     COMMODITY LLDPE TAISOX 3470 QUANTITY 320MT 2FC...
# 7     COMMODITY                                     ...
# 9     COMMODITY                                     ...
# ...                                                 ...
# 8403  COMMODITY            MONO ETHYLENE GLYCOLx000D...
# 8413  CFR KOBE JAPANx000DVISCOSE RAYON STAPLE FIBERx...
# 8414  DESCRIPTION OF GOODS QUANTITYMT UNIT PRICEUSDM...
# 8415  DESCRIPTION OF GOODS QUANTITYMT UNIT PRICEUSDM...
# 8416  DESCRIPTION OF GOODS QUANTITYMT UNIT PRICEUSDM...
#
#                                                     46A  \
# 3     1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4     1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 5     1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 7     +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 9     +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# ...                                                 ...
# 8403  1.SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS IND...
# 8413  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 8414  +SIGNED AND STAMPED COMMERCIAL INVOICE IN 3 OR...
# 8415  +SIGNED AND STAMPED COMMERCIAL INVOICE IN 3 OR...
# 8416  +SIGNED AND STAMPED COMMERCIAL INVOICE IN 3 OR...
#
#                                                     47A  \
# 3     1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4     (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 5     +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 7     ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 9     ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# ...                                                 ...
# 8403  1. ALL DOCUMENTS MUST BE DATED, SIGNED AND ISS...
# 8413  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 8414  +KINDLY ASSIST US TO RELAY THIS CREDIT TO CITI...
# 8415  +KINDLY ASSIST US TO RELAY THIS CREDIT TO CITI...
# 8416  +KINDLY ASSIST US TO RELAY THIS CREDIT TO CITI...
#
#                                       31D     44C  \
# 3                            210321TAIWAN  210228
# 4                            210221TAIWAN     NaN
# 5                        210315 IN TAIWAN  210215
# 7     210404IN THE COUNTRY OF BENEFICIARY  210320
# 9     210404IN THE COUNTRY OF BENEFICIARY  210320
# ...                                   ...     ...
# 8403  210710AT NEGOTIATING BANK'S COUNTER  210630
# 8413        210925AT THE NEGOTIATING BANK  210910
# 8414                         210724TAIWAN  210714
# 8415                         210724TAIWAN  210714
# 8416                         210724TAIWAN  210714
#
#                                         48  \
# 3         21/(REFER FIELD 47A CLAUSE NO.8)
# 4                                      021
# 5     10/AFTER DATE OF TRANSPORT DOCUMENTS
# 7                                       15
# 9                                       15
# ...                                    ...
# 8403             10/AFTER B/L ISSUING DATE
# 8413                                   015
# 8414                            10/SEE 47A
# 8415                            10/SEE 47A
# 8416                            10/SEE 47A
#
#                                                     71D  \
# 3     ALL BANK CHARGES OUTSIDE INDIA ARETO THE ACCOU...
# 4                                                   NaN
# 5     ALL BANKING CHARGES OUTSIDE VIETNAMINCLUDING R...
# 7     ALL BANKING CHARGES OUTSIDE JAPANARE FOR BENEF...
# 9     ALL BANKING CHARGES OUTSIDE JAPANARE FOR BENEF...
# ...                                                 ...
# 8403  +ALL BANKING CHARGES OUTSIDE OUR_x000D_\n COUN...
# 8413  ALL BANKING CHGS INCLUDING REIMB_x000D_\nCOMM ...
# 8414  ALL BANKING CHARGES EXCEPT L/C_x000D_\nOPENING...
# 8415  ALL BANKING CHARGES EXCEPT L/C_x000D_\nOPENING...
# 8416  ALL BANKING CHARGES EXCEPT L/C_x000D_\nOPENING...
#
#                                                      78  \
# 3     +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4     IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 5     + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 7     ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 9     ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# ...                                                 ...
# 8403  +THE AMOUNT OF EACH DRAWING UNDER THIS CREDIT ...
# 8413  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 8414  +TO NEGOTIATING BANK ONLY : PLEASE FORWARD ALL...
# 8415  +TO NEGOTIATING BANK ONLY : PLEASE FORWARD ALL...
# 8416  +TO NEGOTIATING BANK ONLY : PLEASE FORWARD ALL...
#
#                                                      50          51A  \
# 3     OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...          NaN
# 4     AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...          NaN
# 5     MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...  VBAAVNVX310
# 7     CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...          NaN
# 9     CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...          NaN
# ...                                                 ...          ...
# 8403  HENGLI PETROCHEMICAL CO., LIMITED_x000D_\nFLAT...          NaN
# 8413  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...          NaN
# 8414  XIAMEN GOLDEN CHEMICALS CO., LTD_x000D_\nADDRE...          NaN
# 8415  XIAMEN GOLDEN CHEMICALS CO., LTD_x000D_\nADDRE...          NaN
# 8416  XIAMEN GOLDEN CHEMICALS CO., LTD_x000D_\nADDRE...          NaN
#
#                   LCNO                from EXPNO  \
# 3      6281MLC00000321  017-202101-03.xlsx    11
# 4              L072875  017-202101-03.xlsx    27
# 5     2100ILS210100001  017-202101-03.xlsx    18
# 7       LC008000033701  017-202101-03.xlsx    25
# 9       LC008000033701  017-202101-03.xlsx    25
# ...                ...                 ...   ...
# 8403   810LC210000936D  822-202101-06.xlsx    2A
# 8413   101LCS-67769333  822-202101-06.xlsx    41
# 8414  868IUSN211740001  822-202101-06.xlsx    4A
# 8415  868IUSN211740001  822-202101-06.xlsx    4A
# 8416  868IUSN211740001  822-202101-06.xlsx    4A
#
#                                                    LCBK  \
# 3     ICICI BANK LTD.,\nSHALIMAR TOWER, 31/54 M.G.MA...
# 4          NATIONAL COMMERCIAL BANK, THE\n(HEAD OFFICE)
# 5     VIET NAM BANK FOR AGRICULTURE \nAND RURAL DEVE...
# 7                      THE MIZUHO BANK,LTD.,HEAD OFFICE
# 9                      THE MIZUHO BANK,LTD.,HEAD OFFICE
# ...                                                 ...
# 8403                   AGRICULTURAL BANK OF \nCHINA LTD
# 8413        SUMITOMO MITSUI BANKING \nCORPORATION JAPAN
# 8414                                 CTBC BANK CO.,LTD.
# 8415                                 CTBC BANK CO.,LTD.
# 8416                                 CTBC BANK CO.,LTD.
#
#                                                     CU1  \
# 3     OJUS PETROCHEMICALS LLPC 289 NIRALA\n NAGAR LU...
# 4     AHMED SAEED AFIFI FACTORY CO. FORRE\nSINS LTD....
# 5     MINH KHANG CHEMICAL TRADINGJOINT ST\nOCK COMPA...
# 7     CHORI CO., LTD.TEL NO.81-76-232-300\n8FAX NO.8...
# 9     CHORI CO., LTD.TEL NO.81-76-232-300\n8FAX NO.8...
# ...                                                 ...
# 8403                  HENGLI PETROCHEMICAL CO., LIMITED
# 8413  MARUBENI INTEX CO.,LTD.\n1-2-1 DOJIMAHAMA, KIT...
# 8414                     XIAMEN GOLDEN CHEMICALS CO LTD
# 8415                     XIAMEN GOLDEN CHEMICALS CO LTD
# 8416                     XIAMEN GOLDEN CHEMICALS CO LTD
#
#                                                  SPEC  \
# 3                                 MASS PVC RESIN B-57
# 4                                  PHTHALIC ANHYDRIDE
# 5     LINEAR LOW DENSITYPOLYETHYLENE RESINTAISOX 3470
# 7                     POLYESTER PARTIALYORIENTED YARN
# 9                             POLYESTER FILAMENT YARN
# ...                                               ...
# 8403                             MONO ETHYLENE GLYCOL
# 8413     VISCOSE RAYON STAPLE FIBER15DX40MM SEMI DULL
# 8414                          PC RESIN GRADE NOAC2916
# 8415                     PC RESIN GRADE NOAC2820-A320
# 8416                     PC RESIN GRADE NOAC3835-A00E
#
#                        Baodian_predict
# 3                       PVC RESIN B-57
# 4                PHTHALIC ANHYDRIDE PA
# 5                         LLDPE TAISOX
# 7     POLYESTER PARTIALY ORIENTED YARN
# 9     POLYESTER PARTIALY ORIENTED YARN
# ...                                ...
# 8403              MONO ETHYLENE GLYCOL
# 8413        VISCOSE RAYON STAPLE FIBER
# 8414                          PC RESIN
# 8415                          PC RESIN
# 8416                          PC RESIN
#
# [3643 rows x 18 columns]

# %% [markdown]
# # 製作Y_label

# %%
ok_ = 0
no_ = 0
y_label = []

for i in tqdm(range(len(df))):
    # 1.判斷SPEC是否匹配
    if str(df['SPEC'].values[i]) in str(df['45A'].values[i]):
        y_label.append(df['SPEC'].values[i])
        ok_ += 1
        continue #continue：強制跳出 ❮本次❯ 迴圈，繼續進入下一圈
    
    # 2.如果SPEC無法匹配到則可以判斷寶典是否匹配
    if str(df['Baodian_predict'].values[i]) in str(df['45A'].values[i]):
        y_label.append(df['Baodian_predict'].values[i])
        ok_ += 1
        continue #continue：強制跳出 ❮本次❯ 迴圈，繼續進入下一圈
    
    # 3.如果都不匹配 則會觸發以下程序
    no_ += 1
    y_label.append(np.nan)

print(ok_,no_)
df['Y_label'] = y_label
df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
#   0%|          | 0/3643 [00:00<?, ?it/s]
# 3618 25
#                                                   59  \
# 3  FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4  NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 5  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 7  NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 9  NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
#
#                                                  45A  \
# 3  MASS PVC RESIN B-57QUANTITY 175 MT AT 1300 USD...
# 4  PHTHALIC ANHYDRIDE PAQUANTITY  306 MT UNIT PRI...
# 5  COMMODITY LLDPE TAISOX 3470 QUANTITY 320MT 2FC...
# 7  COMMODITY                                     ...
# 9  COMMODITY                                     ...
#
#                                                  46A  \
# 3  1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4  1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 5  1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 7  +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 9  +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
#
#                                                  47A  \
# 3  1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4  (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 5  +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 7  ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 9  ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
#
#                                    31D     44C  \
# 3                         210321TAIWAN  210228
# 4                         210221TAIWAN     NaN
# 5                     210315 IN TAIWAN  210215
# 7  210404IN THE COUNTRY OF BENEFICIARY  210320
# 9  210404IN THE COUNTRY OF BENEFICIARY  210320
#
#                                      48  \
# 3      21/(REFER FIELD 47A CLAUSE NO.8)
# 4                                   021
# 5  10/AFTER DATE OF TRANSPORT DOCUMENTS
# 7                                    15
# 9                                    15
#
#                                                  71D  \
# 3  ALL BANK CHARGES OUTSIDE INDIA ARETO THE ACCOU...
# 4                                                NaN
# 5  ALL BANKING CHARGES OUTSIDE VIETNAMINCLUDING R...
# 7  ALL BANKING CHARGES OUTSIDE JAPANARE FOR BENEF...
# 9  ALL BANKING CHARGES OUTSIDE JAPANARE FOR BENEF...
#
#                                                   78  \
# 3  +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4  IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 5  + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 7  ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 9  ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
#
#                                                   50          51A  \
# 3  OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...          NaN
# 4  AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...          NaN
# 5  MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...  VBAAVNVX310
# 7  CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...          NaN
# 9  CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...          NaN
#
#                LCNO                from EXPNO  \
# 3   6281MLC00000321  017-202101-03.xlsx    11
# 4           L072875  017-202101-03.xlsx    27
# 5  2100ILS210100001  017-202101-03.xlsx    18
# 7    LC008000033701  017-202101-03.xlsx    25
# 9    LC008000033701  017-202101-03.xlsx    25
#
#                                                 LCBK  \
# 3  ICICI BANK LTD.,\nSHALIMAR TOWER, 31/54 M.G.MA...
# 4       NATIONAL COMMERCIAL BANK, THE\n(HEAD OFFICE)
# 5  VIET NAM BANK FOR AGRICULTURE \nAND RURAL DEVE...
# 7                   THE MIZUHO BANK,LTD.,HEAD OFFICE
# 9                   THE MIZUHO BANK,LTD.,HEAD OFFICE
#
#                                                  CU1  \
# 3  OJUS PETROCHEMICALS LLPC 289 NIRALA\n NAGAR LU...
# 4  AHMED SAEED AFIFI FACTORY CO. FORRE\nSINS LTD....
# 5  MINH KHANG CHEMICAL TRADINGJOINT ST\nOCK COMPA...
# 7  CHORI CO., LTD.TEL NO.81-76-232-300\n8FAX NO.8...
# 9  CHORI CO., LTD.TEL NO.81-76-232-300\n8FAX NO.8...
#
#                                               SPEC  \
# 3                              MASS PVC RESIN B-57
# 4                               PHTHALIC ANHYDRIDE
# 5  LINEAR LOW DENSITYPOLYETHYLENE RESINTAISOX 3470
# 7                  POLYESTER PARTIALYORIENTED YARN
# 9                          POLYESTER FILAMENT YARN
#
#                     Baodian_predict                           Y_label
# 3                    PVC RESIN B-57               MASS PVC RESIN B-57
# 4             PHTHALIC ANHYDRIDE PA                PHTHALIC ANHYDRIDE
# 5                      LLDPE TAISOX                      LLDPE TAISOX
# 7  POLYESTER PARTIALY ORIENTED YARN  POLYESTER PARTIALY ORIENTED YARN
# 9  POLYESTER PARTIALY ORIENTED YARN           POLYESTER FILAMENT YARN

# %% [markdown]
# # 斷詞模型

# %%
import wordninja
from wordninja import LanguageModel
import re

寶典 = pd.read_excel('台塑企業_ 產品寶典20210303.xlsx')
產品集合 = list(set(寶典['品名'].values))
產品集合 = [str(i).lower() for i in 產品集合]
print(產品集合[:5])

with open('wordninja_words.txt',encoding="utf-8") as f:
    wordninja_words_lst = f.read().split('\n')
print(wordninja_words_lst[:5])

SPEC集合 = df['Y_label'].values.tolist()
SPEC集合 = [str(i).lower() for i in SPEC集合]
print(SPEC集合[:5])

全部集合 = list(set(產品集合+SPEC集合+wordninja_words_lst))
print(全部集合[:5])

with open('全部集合.txt', 'w',encoding="utf-8") as f:
    lines = [i + '\n' for i in 全部集合]
    f.writelines(lines)
import gzip
import shutil
with open('全部集合.txt', 'rb') as f_in, gzip.open('全部集合.txt.gz', 'wb') as f_out:
    shutil.copyfileobj(f_in, f_out)

class LanguageModel2(LanguageModel):
    def split(self, s):
        _SPLIT_RE = re.compile("[^a-zA-Z0-9-']+")
        l = [self._split(x) for x in _SPLIT_RE.split(s)]
        return [item for sublist in l for item in sublist]

lm = LanguageModel2('全部集合.txt.gz')
' '.join(lm.split(df['45A'].values[0]))
# Out:
# ['polyester dty', 'fiberglass doors with overlap composite', 'vinyl ester resin', 'pvc printed films', 'isob vianol iba']
# ['the', 'of', 'in', 'a', 'and']
# ['mass pvc resin b-57', 'phthalic anhydride', 'lldpe taisox', 'polyester partialy oriented yarn', 'polyester filament yarn']
# ['', 'singles', 'tupac', 'gyu', 'sture']
# 'MASS PVC RESIN B-57 QUANTITY 175 MT AT 1300 US DM TAS PER PROFORMA INVOICE NO A 0 B 002 - 11 D A T E D 10 - 12 - 2020 C I F PIPA VAV PORT INDIA IN COTE RMS 2010'

# %% [markdown]
# # 斷詞處理

# %%
lst = []
for i in tqdm(range(len(df))):
    lst.append(' '.join(lm.split(df['45A'].values[i])))
df['45A'] = lst
df[['45A','Y_label','SPEC']].head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/3643 [00:00<?, ?it/s]
#                                                  45A  \
# 3  MASS PVC RESIN B-57 QUANTITY 175 MT AT 1300 US...
# 4  PHTHALIC ANHYDRIDE PA QUANTITY 306 MT UNIT PRI...
# 5  COMMODITY LLDPE TAISOX 3470 QUANTITY 320 MT 2 ...
# 7  COMMODITY AMOUNT POLYESTER TEXTURED YAR NHS CO...
# 9  COMMODITY AMOUNT POLYESTER TEXTURED YAR NHS CO...
#
#                             Y_label  \
# 3               MASS PVC RESIN B-57
# 4                PHTHALIC ANHYDRIDE
# 5                      LLDPE TAISOX
# 7  POLYESTER PARTIALY ORIENTED YARN
# 9           POLYESTER FILAMENT YARN
#
#                                               SPEC
# 3                              MASS PVC RESIN B-57
# 4                               PHTHALIC ANHYDRIDE
# 5  LINEAR LOW DENSITYPOLYETHYLENE RESINTAISOX 3470
# 7                  POLYESTER PARTIALYORIENTED YARN
# 9                          POLYESTER FILAMENT YARN

# %% [markdown]
# # 清洗

# %%
df = df.dropna(subset=['45A','Y_label'],axis=0).reset_index(drop=True)
print(df.shape)
keep_lst = []
for i in range(len(df)):
    if df.iloc[i]['Y_label'] in df.iloc[i]['45A']:
        keep_lst.append(i)
df = df.iloc[keep_lst]
print(df.shape)
# Out:
# (3618, 19)
# (3224, 19)

# %%
df[['45A','Y_label']].head()
# Out:
#                                                  45A              Y_label
# 0  MASS PVC RESIN B-57 QUANTITY 175 MT AT 1300 US...  MASS PVC RESIN B-57
# 1  PHTHALIC ANHYDRIDE PA QUANTITY 306 MT UNIT PRI...   PHTHALIC ANHYDRIDE
# 2  COMMODITY LLDPE TAISOX 3470 QUANTITY 320 MT 2 ...         LLDPE TAISOX
# 5  ITEM 1 HDPE TAISOX 8010 200 MT USD 1100 MT CON...     HDPE TAISOX 8010
# 6  ITEM 1 HDPE TAISOX 8010 200 MT USD 1100 MT CON...     HDPE TAISOX 8010

# %% [markdown]
# # 起始結束標註

# %%
def str2index(context,string):
    ys = context.find(string)
    ye = ys + len(string)
    return ys,ye

ys_lst = []
ye_lst = []
for i in range(len(df)):
    context= df['45A'].values[i]
    string = df['Y_label'].values[i]
    ys,ye = str2index(context,string)
    ys_lst.append(ys)
    ye_lst.append(ye)
df['string_Y_1'] = ys_lst
df['string_Y_2'] = ye_lst
df.head()
# Out:
#                                                   59  \
# 0  FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 1  NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 2  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 5  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 6  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
#
#                                                  45A  \
# 0  MASS PVC RESIN B-57 QUANTITY 175 MT AT 1300 US...
# 1  PHTHALIC ANHYDRIDE PA QUANTITY 306 MT UNIT PRI...
# 2  COMMODITY LLDPE TAISOX 3470 QUANTITY 320 MT 2 ...
# 5  ITEM 1 HDPE TAISOX 8010 200 MT USD 1100 MT CON...
# 6  ITEM 1 HDPE TAISOX 8010 200 MT USD 1100 MT CON...
#
#                                                  46A  \
# 0  1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 1  1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 2  1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 5  +1.SIGNED COMMERCIAL INVOICE IN 3 ORIGINAL (S)...
# 6  +1.SIGNED COMMERCIAL INVOICE IN 3 ORIGINAL (S)...
#
#                                                  47A  \
# 0  1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 1  (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 2  +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 5  +EACH SET OF DOCUMENTS PRESENTED WITH DISCREPA...
# 6  +EACH SET OF DOCUMENTS PRESENTED WITH DISCREPA...
#
#                                31D     44C  \
# 0                     210321TAIWAN  210228
# 1                     210221TAIWAN     NaN
# 2                 210315 IN TAIWAN  210215
# 5  210314IN COUNTRY OF BENEFICIARY  210228
# 6  210314IN COUNTRY OF BENEFICIARY  210228
#
#                                      48  \
# 0      21/(REFER FIELD 47A CLAUSE NO.8)
# 1                                   021
# 2  10/AFTER DATE OF TRANSPORT DOCUMENTS
# 5        014/AFTER THE DATE OF SHIPMENT
# 6        014/AFTER THE DATE OF SHIPMENT
#
#                                                  71D  \
# 0  ALL BANK CHARGES OUTSIDE INDIA ARETO THE ACCOU...
# 1                                                NaN
# 2  ALL BANKING CHARGES OUTSIDE VIETNAMINCLUDING R...
# 5  ALL BANKING CHARGES OUTSIDE THEISSUING BANK IN...
# 6  ALL BANKING CHARGES OUTSIDE THEISSUING BANK IN...
#
#                                                   78  \
# 0  +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 1  IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 2  + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 5  + FORWARD DRAFTS AND DOCUMENTS TO STANDARD CHA...
# 6  + FORWARD DRAFTS AND DOCUMENTS TO STANDARD CHA...
#
#                                                   50  ...              LCNO  \
# 0  OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...  ...   6281MLC00000321
# 1  AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...  ...           L072875
# 2  MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...  ...  2100ILS210100001
# 5  TOPRANK CHEMICAL CO., LIMITEDLEVEL 54 HOPEWELL...  ...    108013002994-L
# 6  TOPRANK CHEMICAL CO., LIMITEDLEVEL 54 HOPEWELL...  ...    108013002994-L
#
#                  from EXPNO  \
# 0  017-202101-03.xlsx    11
# 1  017-202101-03.xlsx    27
# 2  017-202101-03.xlsx    18
# 5  017-202101-03.xlsx    18
# 6  017-202101-03.xlsx    18
#
#                                                 LCBK  \
# 0  ICICI BANK LTD.,\nSHALIMAR TOWER, 31/54 M.G.MA...
# 1       NATIONAL COMMERCIAL BANK, THE\n(HEAD OFFICE)
# 2  VIET NAM BANK FOR AGRICULTURE \nAND RURAL DEVE...
# 5  STANDARD CHARTERED BANK (CHINA) \nLIMITED (HAN...
# 6  STANDARD CHARTERED BANK (CHINA) \nLIMITED (HAN...
#
#                                                  CU1  \
# 0  OJUS PETROCHEMICALS LLPC 289 NIRALA\n NAGAR LU...
# 1  AHMED SAEED AFIFI FACTORY CO. FORRE\nSINS LTD....
# 2  MINH KHANG CHEMICAL TRADINGJOINT ST\nOCK COMPA...
# 5  TOPRANK CHEMICAL CO., LIMITEDLEVEL \n54 HOPEWE...
# 6  TOPRANK CHEMICAL CO., LIMITEDLEVEL \n54 HOPEWE...
#
#                                               SPEC        Baodian_predict  \
# 0                              MASS PVC RESIN B-57         PVC RESIN B-57
# 1                               PHTHALIC ANHYDRIDE  PHTHALIC ANHYDRIDE PA
# 2  LINEAR LOW DENSITYPOLYETHYLENE RESINTAISOX 3470           LLDPE TAISOX
# 5                   HIGH DENSITYPOLYETHYLENE RESIN       HDPE TAISOX 8010
# 6      ETHYLENE VINYL ACETATECOPOLYMERTAISOX 7360M       HDPE TAISOX 8010
#
#                Y_label string_Y_1  string_Y_2
# 0  MASS PVC RESIN B-57          0          19
# 1   PHTHALIC ANHYDRIDE          0          18
# 2         LLDPE TAISOX         10          22
# 5     HDPE TAISOX 8010          7          23
# 6     HDPE TAISOX 8010          7          23
#
# [5 rows x 21 columns]

# %%
assert df['45A'].values[0][df['string_Y_1'].values[0]:df['string_Y_2'].values[0]] == df['Y_label'].values[0]

# %%
for i in range(10):
    print(df['45A'].values[i][df['string_Y_1'].values[i]:df['string_Y_2'].values[i]],df['Y_label'].values[i])
# Out:
# MASS PVC RESIN B-57 MASS PVC RESIN B-57
# PHTHALIC ANHYDRIDE PHTHALIC ANHYDRIDE
# LLDPE TAISOX LLDPE TAISOX
# HDPE TAISOX 8010 HDPE TAISOX 8010
# HDPE TAISOX 8010 HDPE TAISOX 8010
# HDPE TAISOX 8010 HDPE TAISOX 8010
# TAISOX TAISOX
# GASOIL GASOIL
# GASOIL GASOIL
# EVA TAISOX EVA TAISOX

# %%
print(df.shape)
# Out:
# (3224, 21)

# %% [markdown]
# # 保存

# %%
df.to_csv('preprocess_for_SQUAD_product.csv')
